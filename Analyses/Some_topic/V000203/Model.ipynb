# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.decomposition import PCA
import Functions.Model as fmod
import Functions.General as fgen
import Functions.Preparation as fprep
import config_main as cm
import Configuration.config_model as cmod
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

# %load_ext autoreload
# %autoreload 2
plt.style.use('ggplot')

# %%
# Loading train and correct types
train = pd.read_csv(cm.train)
# convert just columns "a" and "b"
train = fprep.convert_columns_with_function(train, 'object', 'PassengerId')
train.dtypes
# Out:
# PassengerId     object
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Quick data check
train.describe(include='all')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>891.0</td>
#       <td>891.000000</td>
#       <td>891.000000</td>
#       <td>891</td>
#       <td>891</td>
#       <td>714.000000</td>
#       <td>891.000000</td>
#       <td>891.000000</td>
#       <td>891</td>
#       <td>891.000000</td>
#       <td>204</td>
# ...

# %%
fprep.describe_features(train, timeline=False)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#
# Length of dataframe: 891
# Describing: Survived
# Quantiles:
#  0.00    0.0
# 0.25    0.0
# 0.50    0.0
# 0.75    1.0
# 1.00    1.0
# Name: Survived, dtype: float64
# ____________________________________________________________________________________________________
#
# Describing: Pclass
# Quantiles:
#  0.00    1.0
# 0.25    2.0
# 0.50    3.0
# 0.75    3.0
# 1.00    3.0
# Name: Pclass, dtype: float64
# ____________________________________________________________________________________________________
#
# Describing: Age
# Quantiles:
#  0.00     0.420
# 0.25    20.125
# 0.50    28.000
# 0.75    38.000
# 1.00    80.000
# Name: Age, dtype: float64
# ____________________________________________________________________________________________________
#
# Describing: SibSp
# Quantiles:
#  0.00    0.0
# 0.25    0.0
# 0.50    0.0
# ...

# %%
train_filtered = fprep.filter_variables(df=train, Parch='<5')
train_filtered = train_filtered.dropna(subset=['PassengerId'])
len(train_filtered)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#
# Filtering dataframe. Length of dataframe before filtering: 891
# Filtering: Parch <5
#
# Quantiles BEFORE filtering:
#  0.00    0.0
# 0.25    0.0
# 0.50    0.0
# 0.75    0.0
# 1.00    6.0
# Name: Parch, dtype: float64
# Quantiles AFTER filtering:
#  0.00    0.0
# 0.25    0.0
# 0.50    0.0
# 0.75    0.0
# 1.00    4.0
# Name: Parch, dtype: float64
# Length of dataframe after filtering: 885
# ____________________________________________________________________________________________________
#
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# 885

# %%
train_imputed = train_filtered
train_imputed['Age'] = train_filtered.Age.fillna(train_filtered.Age.mean())
train_imputed['Embarked'] = train_filtered.Embarked.fillna('OTHER')

# %%
train_encoded = train_imputed
from sklearn.preprocessing import LabelEncoder

le_embarked = LabelEncoder()
le_sex = LabelEncoder()
train_encoded['Embarked'] = le_embarked.fit_transform(train_encoded.Embarked)
train_encoded['Sex'] = le_sex.fit_transform(train_encoded.Sex)

# %%
from sklearn.model_selection import train_test_split

x_train = train_encoded.drop(['Survived', 'PassengerId', 'Name', 'Ticket', 'Cabin'], 1)
y_train = train_encoded.Survived

# %%
gs = train_encoded.boxplot(by='Survived', column='Age')
plt.show()
train_encoded.groupby('Survived').mean()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Pclass</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#       <th>Embarked</th>
#     </tr>
#     <tr>
#       <th>Survived</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2.527574</td>
#       <td>0.858456</td>
#       <td>30.305431</td>
#       <td>0.553309</td>
#       <td>0.284926</td>
#       <td>21.993488</td>
#       <td>2.501838</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %%
fmod.plot_tree(x_train, y_train, cm.tree)
# Out:
# <generator object model_error at 0x0000020DFD45B620>

# %%
gs = cmod.grid_search
gs.fit(x_train, y_train)
gs_results = pd.DataFrame(gs.cv_results_)
gs_results['Version'] = cm.currentVersion
gs_results.to_csv(cm.gridsearch_log, mode='a')

# %%
from sklearn.metrics import make_scorer, accuracy_score

perfect_model = gs.best_estimator_
fmod.model_summary(x_train, y_train, perfect_model, 'accuracy', cm.model_results_pdf)
y_test, y_pred = fmod.train_predict(x_train, y_train, perfect_model, test_size=0.3)
fmod.my_roc_curve(y_test, y_pred)
# Out:
# accuracy test results: [ 0.79213483  0.83050847  0.87570621  0.81355932  0.85227273]
# accuracy test mean: 0.83
# accuracy test mean: 0.83
# C:\Users\Jan Janiszewski\PycharmProjects\Example\Functions\Model.py:122: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   # Best fit line
# Creating ROC not possible
# True

# %%
g = fmod.my_learning_curve(x_train, y_train, perfect_model, 5, 'accuracy')
# Out:
# [learning_curve] Training set sizes: [ 70 141 212 282 353 424 494 565 636 707]
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:   34.3s finished
# True

# %%
fmod.my_visual_parameter_tuning(x_train, y_train, perfect_model, 
                                'clf__max_depth', 5, [3,5,10])
# Out:
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   11.7s finished
# True

# %%
from sklearn.metrics import make_scorer, accuracy_score

dummy_model = gs.estimator
t = fmod.plot_real_pred(x_train, y_train, dummy_model)
t = fmod.plot_residuals(x_train, y_train, dummy_model)
# Out:
# C:\Users\Jan Janiszewski\PycharmProjects\Example\Functions\Model.py:100: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   clf2.fit(y_test.reshape(-1, 1), y_pred)
