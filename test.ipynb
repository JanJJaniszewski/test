# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.decomposition import PCA
import Functions.Model as fmod
import Functions.General as fgen
import config_main as cm
from Configuration.config_model import *
from Configuration.config_variables import *
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

iris = datasets.load_iris()
x = iris.data[:, :2]  # we only take the first two features.
y = iris.target

# %load_ext autoreload
# %autoreload 2
plt.style.use('ggplot')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fgen.new_model(typ='m', model_path=cm.model, message='First good model')

# %%
clf = DecisionTreeClassifier()
plot1 = fmod.plot_real_pred(x, y, clf)

# %%
fmod.model_summary(x, y, clf, ['r2'], cm.model_results)
# Out:
# r2 test results: [ 0.55  0.55  0.6   0.65  0.5 ]
# r2 test mean: 0.57
# r2 test mean: 0.57

# %%
fmod.plot_tree(x, y, typ='classification', output_path=)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-d47366db7c65> in <module>()
# ----> 1 fmod.plot_tree(x, y, typ='classification')
#
# TypeError: plot_tree() missing 1 required positional argument: 'output_path'
